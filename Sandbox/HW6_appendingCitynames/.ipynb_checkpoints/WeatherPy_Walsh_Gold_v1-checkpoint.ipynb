# %% [markdown]
# # WeatherPy_Walsh_Gold
# ----
#
# #### Note
# * Instructions have been included for each segment. You do not have to follow them exactly, but they are included to help you think through the steps.

# %%
#!pip install gmaps
#!pip install ipywidgets
#!jupyter nbextension enable --py widgetsnbextension
#!pip install citipy
#!pip install openweathermapy

# %%
# Dependencies and Setup
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np
import requests
import time
import sys
import json
import csv
import datetime

import openweathermapy.core as owm
import os  # For getting API key from computer

# %%
# Incorporated citipy to determine city based on latitude and longitude
from citipy import citipy

## tried to get key from os
api_key = os.environ.get('weather_api_key')

# Output File (CSV)
output_data_file = "output_data/cities.csv"

# %% [markdown]
# ## Generate Cities List

# %%
## Generate random latitude and longitudes
# Range of latitudes and longitudes
lat_range = (-90, 90)
lng_range = (-180, 180)

# List for holding lat_lngs tuples
lat_lng_rand = []

# Create a set of random lat and lng combinations
lats = np.random.uniform(low=-90.000, high=90.000, size=1500)
lngs = np.random.uniform(low=-180.000, high=180.000, size=1500)
lat_lng_rand = zip(lats, lngs)

## Generate cities list from random latitudes and longitudes using citipy.nearest_city
# List for holding cities
cities = []

# Identify nearest city for each lat, lng combination
for lat_lng in lat_lng_rand:
    city = citipy.nearest_city(lat_lng[0], lat_lng[1]).city_name
    
    # If the city is unique, then add it to a our cities list
    if city not in cities:
        cities.append(city)

# Print the city count to confirm sufficient count
len(cities)
# Out:
# 616

# %% [markdown]
# ### Perform API Calls
# * Perform a weather check on each city using a series of successive API calls.
# * Include a print log of each city as it'sbeing processed (with the city number and city name).

# %%
# Set api for openweathermap
url = "http://api.openweathermap.org/data/2.5/weather?"

# Create settings dictionary for key parameters
settings = {"units": "imperial", "appid": api_key}

city_name_name = ['name','clouds.all','sys.country','dt',
                  'main.humidity','coord.lat','coord.lon','main.temp_max','wind.speed']

all_in_one = []
count = 0
rec = 0
set = 1

for city in cities:

    if count == 50:
        time.sleep(1.1)
        count = 0
        rec = 0
        set+=1
    try:
        # Openweathermap API call to get current weather for a city
        current_weather_city = owm.get_current(city, **settings)
        awesome_city = current_weather_city(*city_name_name)
        count += 1
        rec += 1

        print(f"Processing Record {rec} of Set {set} | {current_weather_city['name']}.")
        all_in_one.append(awesome_city)

    except:
        print("City not found. Skipping...")
# Out:
# Processing Record 1 of Set 1 | Codrington.
# Processing Record 2 of Set 1 | Katsuura.
# Processing Record 3 of Set 1 | Castro.
# Processing Record 4 of Set 1 | Saint-Philippe.
# Processing Record 5 of Set 1 | Kaeo.
# Processing Record 6 of Set 1 | Kruisfontein.
# Processing Record 7 of Set 1 | Ribeira Grande.
# Processing Record 8 of Set 1 | Rikitea.
# City not found. Skipping...
# Processing Record 9 of Set 1 | Pevek.
# Processing Record 10 of Set 1 | Portland.
# Processing Record 11 of Set 1 | Carnarvon.
# Processing Record 12 of Set 1 | Lompoc.
# Processing Record 13 of Set 1 | Mataura.
# Processing Record 14 of Set 1 | Padang.
# Processing Record 15 of Set 1 | Khatanga.
# Processing Record 16 of Set 1 | Aleksandrovka.
# Processing Record 17 of Set 1 | Kudahuvadhoo.
# Processing Record 18 of Set 1 | Butaritari.
# City not found. Skipping...
# Processing Record 19 of Set 1 | Vinkovci.
# Processing Record 20 of Set 1 | Bluff.
# Processing Record 21 of Set 1 | Fortuna.
# Processing Record 22 of Set 1 | Saint Anthony.
# Processing Record 23 of Set 1 | Jamestown.
# Processing Record 24 of Set 1 | Omboue.
# City not found. Skipping...
# Processing Record 25 of Set 1 | Cape Town.
# Processing Record 26 of Set 1 | Lasa.
# Processing Record 27 of Set 1 | Longyearbyen.
# Processing Record 28 of Set 1 | Manakara.
# Processing Record 29 of Set 1 | Sept-Iles.
# Processing Record 30 of Set 1 | Busselton.
# Processing Record 31 of Set 1 | Belyy Yar.
# Processing Record 32 of Set 1 | Ushuaia.
# Processing Record 33 of Set 1 | Yumen.
# Processing Record 34 of Set 1 | Batagay-Alyta.
# Processing Record 35 of Set 1 | Provideniya.
# Processing Record 36 of Set 1 | Kibala.
# Processing Record 37 of Set 1 | Norman Wells.
# Processing Record 38 of Set 1 | Mocuba.
# Processing Record 39 of Set 1 | Vaini.
# Processing Record 40 of Set 1 | Sambava.
# Processing Record 41 of Set 1 | Severo-Kurilsk.
# Processing Record 42 of Set 1 | Qaanaaq.
# Processing Record 43 of Set 1 | Mangalore.
# Processing Record 44 of Set 1 | Bredasdorp.
# Processing Record 45 of Set 1 | Tiarei.
# Processing Record 46 of Set 1 | Nanortalik.
# Processing Record 47 of Set 1 | Kiri Buru.
# Processing Record 48 of Set 1 | North Platte.
# Processing Record 49 of Set 1 | Esperance.
# Processing Record 50 of Set 1 | Sayyan.
# Processing Record 1 of Set 2 | Arthur.
# Processing Record 2 of Set 2 | Victoria.
# Processing Record 3 of Set 2 | Vardo.
# Processing Record 4 of Set 2 | Rocha.
# Processing Record 5 of Set 2 | Hithadhoo.
# Processing Record 6 of Set 2 | Arlit.
# City not found. Skipping...
# Processing Record 7 of Set 2 | Chokurdakh.
# Processing Record 8 of Set 2 | Shakawe.
# Processing Record 9 of Set 2 | Anchorage.
# City not found. Skipping...
# Processing Record 10 of Set 2 | Vikhorevka.
# Processing Record 11 of Set 2 | Atuona.
# Processing Record 12 of Set 2 | Oksovskiy.
# Processing Record 13 of Set 2 | Clyde River.
# Processing Record 14 of Set 2 | Ponta do Sol.
# Processing Record 15 of Set 2 | Chuy.
# Processing Record 16 of Set 2 | Phillipsburg.
# Processing Record 17 of Set 2 | Tuktoyaktuk.
# Processing Record 18 of Set 2 | Port Alfred.
# Processing Record 19 of Set 2 | Malanje.
# Processing Record 20 of Set 2 | Kavaratti.
# Processing Record 21 of Set 2 | Saint George.
# Processing Record 22 of Set 2 | Mahenge.
# Processing Record 23 of Set 2 | Saskylakh.
# Processing Record 24 of Set 2 | Hermanus.
# Processing Record 25 of Set 2 | Ituverava.
# Processing Record 26 of Set 2 | Muros.
# Processing Record 27 of Set 2 | Sistranda.
# Processing Record 28 of Set 2 | Punta Arenas.
# Processing Record 29 of Set 2 | Hami.
# Processing Record 30 of Set 2 | Gornopravdinsk.
# Processing Record 31 of Set 2 | Hasaki.
# Processing Record 32 of Set 2 | Marsa Matruh.
# Processing Record 33 of Set 2 | Hambantota.
# Processing Record 34 of Set 2 | Vila Franca do Campo.
# Processing Record 35 of Set 2 | Port Blair.
# Processing Record 36 of Set 2 | Beringovskiy.
# Processing Record 37 of Set 2 | Maham.
# Processing Record 38 of Set 2 | Pontes e Lacerda.
# Processing Record 39 of Set 2 | Kangaatsiaq.
# Processing Record 40 of Set 2 | Zhigansk.
# City not found. Skipping...
# Processing Record 41 of Set 2 | Iqaluit.
# Processing Record 42 of Set 2 | Upernavik.
# City not found. Skipping...
# Processing Record 43 of Set 2 | Torbay.
# Processing Record 44 of Set 2 | Mantua.
# Processing Record 45 of Set 2 | Walvis Bay.
# Processing Record 46 of Set 2 | Anadyr.
# Processing Record 47 of Set 2 | Yellowknife.
# City not found. Skipping...
# Processing Record 48 of Set 2 | Voyvozh.
# Processing Record 49 of Set 2 | Purwodadi.
# Processing Record 50 of Set 2 | Gorontalo.
# Processing Record 1 of Set 3 | Ribas do Rio Pardo.
# Processing Record 2 of Set 3 | Beisfjord.
# Processing Record 3 of Set 3 | Pangody.
# Processing Record 4 of Set 3 | Barrow.
# Processing Record 5 of Set 3 | Saint-Pierre.
# City not found. Skipping...
# Processing Record 6 of Set 3 | Marawi.
# Processing Record 7 of Set 3 | Kula.
# Processing Record 8 of Set 3 | Flinders.
# Processing Record 9 of Set 3 | Hilo.
# Processing Record 10 of Set 3 | Zeya.
# Processing Record 11 of Set 3 | Tera.
# Processing Record 12 of Set 3 | Souillac.
# Processing Record 13 of Set 3 | Banda Aceh.
# City not found. Skipping...
# Processing Record 14 of Set 3 | Champerico.
# Processing Record 15 of Set 3 | Ust-Shonosha.
# Processing Record 16 of Set 3 | East London.
# Processing Record 17 of Set 3 | Tigil.
# Processing Record 18 of Set 3 | Tasiilaq.
# Processing Record 19 of Set 3 | Albany.
# Processing Record 20 of Set 3 | Santa Cruz.
# Processing Record 21 of Set 3 | Bethel.
# Processing Record 22 of Set 3 | Bin Qirdan.
# Processing Record 23 of Set 3 | Garwolin.
# Processing Record 24 of Set 3 | Vanimo.
# Processing Record 25 of Set 3 | Arraial do Cabo.
# Processing Record 26 of Set 3 | Komsomolskiy.
# Processing Record 27 of Set 3 | Nome.
# Processing Record 28 of Set 3 | Pisco.
# Processing Record 29 of Set 3 | Kapaa.
# City not found. Skipping...
# Processing Record 30 of Set 3 | Bambous Virieux.
# Processing Record 31 of Set 3 | Kijang.
# City not found. Skipping...
# Processing Record 32 of Set 3 | Wanning.
# Processing Record 33 of Set 3 | Urengoy.
# Processing Record 34 of Set 3 | Kununurra.
# Processing Record 35 of Set 3 | Soyo.
# Processing Record 36 of Set 3 | Peterhead.
# Processing Record 37 of Set 3 | Banjar.
# Processing Record 38 of Set 3 | Pascagoula.
# Processing Record 39 of Set 3 | Arman.
# Processing Record 40 of Set 3 | Thiers.
# City not found. Skipping...
# Processing Record 41 of Set 3 | New Norfolk.
# Processing Record 42 of Set 3 | Avarua.
# Processing Record 43 of Set 3 | Hay River.
# Processing Record 44 of Set 3 | Kidal.
# Processing Record 45 of Set 3 | Lisala.
# Processing Record 46 of Set 3 | Bud.
# City not found. Skipping...
# Processing Record 47 of Set 3 | Dicabisagan.
# Processing Record 48 of Set 3 | Bandrele.
# City not found. Skipping...
# Processing Record 49 of Set 3 | Hobart.
# City not found. Skipping...
# Processing Record 50 of Set 3 | Grahamstown.
# Processing Record 1 of Set 4 | San Javier.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 2 of Set 4 | Richards Bay.
# Processing Record 3 of Set 4 | Byron Bay.
# Processing Record 4 of Set 4 | Salalah.
# Processing Record 5 of Set 4 | Cabo San Lucas.
# City not found. Skipping...
# Processing Record 6 of Set 4 | Mahajanga.
# Processing Record 7 of Set 4 | Cherskiy.
# Processing Record 8 of Set 4 | Paidha.
# Processing Record 9 of Set 4 | San Patricio.
# Processing Record 10 of Set 4 | Houma.
# Processing Record 11 of Set 4 | Mount Isa.
# Processing Record 12 of Set 4 | Umm Lajj.
# Processing Record 13 of Set 4 | Yulara.
# Processing Record 14 of Set 4 | Batemans Bay.
# Processing Record 15 of Set 4 | Alice Town.
# Processing Record 16 of Set 4 | San Jeronimo.
# Processing Record 17 of Set 4 | Coquimbo.
# Processing Record 18 of Set 4 | Mount Gambier.
# Processing Record 19 of Set 4 | Ballina.
# Processing Record 20 of Set 4 | Thompson.
# Processing Record 21 of Set 4 | Geraldton.
# Processing Record 22 of Set 4 | Carutapera.
# Processing Record 23 of Set 4 | Temerloh.
# Processing Record 24 of Set 4 | Wonthaggi.
# Processing Record 25 of Set 4 | Barkhan.
# Processing Record 26 of Set 4 | Mar del Plata.
# Processing Record 27 of Set 4 | Goalpara.
# City not found. Skipping...
# Processing Record 28 of Set 4 | Buchanan.
# Processing Record 29 of Set 4 | Smolenka.
# Processing Record 30 of Set 4 | Shasta Lake.
# Processing Record 31 of Set 4 | Cidreira.
# Processing Record 32 of Set 4 | Launceston.
# Processing Record 33 of Set 4 | Syumsi.
# Processing Record 34 of Set 4 | Sitka.
# Processing Record 35 of Set 4 | Lodja.
# Processing Record 36 of Set 4 | Olivet.
# Processing Record 37 of Set 4 | Washington DC..
# Processing Record 38 of Set 4 | Jijiga.
# Processing Record 39 of Set 4 | Oksfjord.
# Processing Record 40 of Set 4 | Qasigiannguit.
# Processing Record 41 of Set 4 | Phalodi.
# Processing Record 42 of Set 4 | Georgetown.
# Processing Record 43 of Set 4 | Palu.
# Processing Record 44 of Set 4 | Nouadhibou.
# Processing Record 45 of Set 4 | Maumere.
# Processing Record 46 of Set 4 | Broome.
# Processing Record 47 of Set 4 | Ambulu.
# Processing Record 48 of Set 4 | Mazara del Vallo.
# Processing Record 49 of Set 4 | Port Hedland.
# Processing Record 50 of Set 4 | Sibu.
# City not found. Skipping...
# Processing Record 1 of Set 5 | Valparaiso.
# Processing Record 2 of Set 5 | Kedgwick.
# Processing Record 3 of Set 5 | Formosa.
# Processing Record 4 of Set 5 | Kitsuki.
# Processing Record 5 of Set 5 | Jalu.
# Processing Record 6 of Set 5 | Klaksvik.
# Processing Record 7 of Set 5 | Lebu.
# Processing Record 8 of Set 5 | Kodiak.
# Processing Record 9 of Set 5 | Palana.
# Processing Record 10 of Set 5 | Batagay.
# Processing Record 11 of Set 5 | Port Elizabeth.
# Processing Record 12 of Set 5 | Bonavista.
# Processing Record 13 of Set 5 | Touros.
# Processing Record 14 of Set 5 | Narsaq.
# Processing Record 15 of Set 5 | Faya.
# Processing Record 16 of Set 5 | Sorland.
# Processing Record 17 of Set 5 | Tramandai.
# Processing Record 18 of Set 5 | Kaitangata.
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 19 of Set 5 | Nipawin.
# Processing Record 20 of Set 5 | Ulagan.
# Processing Record 21 of Set 5 | Manisa.
# Processing Record 22 of Set 5 | Tiksi.
# Processing Record 23 of Set 5 | Deputatskiy.
# Processing Record 24 of Set 5 | Litovko.
# Processing Record 25 of Set 5 | Kavieng.
# Processing Record 26 of Set 5 | Nyurba.
# Processing Record 27 of Set 5 | Nikolskoye.
# City not found. Skipping...
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 28 of Set 5 | Ostrovnoy.
# Processing Record 29 of Set 5 | Ulaangom.
# City not found. Skipping...
# Processing Record 30 of Set 5 | Luganville.
# Processing Record 31 of Set 5 | Khuzhir.
# Processing Record 32 of Set 5 | Kargasok.
# Processing Record 33 of Set 5 | Chapais.
# Processing Record 34 of Set 5 | Guerrero Negro.
# Processing Record 35 of Set 5 | Yar-Sale.
# Processing Record 36 of Set 5 | Puerto Ayora.
# Processing Record 37 of Set 5 | Penzance.
# Processing Record 38 of Set 5 | Fomboni.
# Processing Record 39 of Set 5 | Guangyuan.
# Processing Record 40 of Set 5 | Comodoro Rivadavia.
# Processing Record 41 of Set 5 | Trabzon.
# Processing Record 42 of Set 5 | Kholodnyy.
# Processing Record 43 of Set 5 | Nampula.
# Processing Record 44 of Set 5 | Vestmannaeyjar.
# City not found. Skipping...
# Processing Record 45 of Set 5 | Husavik.
# Processing Record 46 of Set 5 | Mitsamiouli.
# City not found. Skipping...
# Processing Record 47 of Set 5 | Berdigestyakh.
# Processing Record 48 of Set 5 | Zyryanka.
# Processing Record 49 of Set 5 | Port Moresby.
# Processing Record 50 of Set 5 | Labuhan.
# City not found. Skipping...
# Processing Record 1 of Set 6 | Rome.
# Processing Record 2 of Set 6 | Evensk.
# Processing Record 3 of Set 6 | Sisimiut.
# Processing Record 4 of Set 6 | Acari.
# Processing Record 5 of Set 6 | Vaasa.
# Processing Record 6 of Set 6 | High Level.
# Processing Record 7 of Set 6 | Kahului.
# Processing Record 8 of Set 6 | Berlevag.
# Processing Record 9 of Set 6 | Constantine.
# Processing Record 10 of Set 6 | Sihora.
# Processing Record 11 of Set 6 | Washougal.
# Processing Record 12 of Set 6 | Bathsheba.
# Processing Record 13 of Set 6 | Kloulklubed.
# Processing Record 14 of Set 6 | Saint-Francois.
# Processing Record 15 of Set 6 | Sheridan.
# Processing Record 16 of Set 6 | Arklow.
# Processing Record 17 of Set 6 | Mastic Beach.
# Processing Record 18 of Set 6 | Prince Rupert.
# Processing Record 19 of Set 6 | The Valley.
# Processing Record 20 of Set 6 | Necochea.
# Processing Record 21 of Set 6 | Kropotkin.
# Processing Record 22 of Set 6 | Salekhard.
# Processing Record 23 of Set 6 | Goderich.
# Processing Record 24 of Set 6 | Tuatapere.
# Processing Record 25 of Set 6 | Talnakh.
# Processing Record 26 of Set 6 | Kaohsiung.
# City not found. Skipping...
# Processing Record 27 of Set 6 | Camacha.
# Processing Record 28 of Set 6 | Bereda.
# Processing Record 29 of Set 6 | Jamame.
# City not found. Skipping...
# Processing Record 30 of Set 6 | Adrar.
# Processing Record 31 of Set 6 | Xai-Xai.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 32 of Set 6 | Mahebourg.
# Processing Record 33 of Set 6 | Tena.
# Processing Record 34 of Set 6 | Mayumba.
# Processing Record 35 of Set 6 | Ashoknagar.
# Processing Record 36 of Set 6 | Harer.
# Processing Record 37 of Set 6 | Kralendijk.
# Processing Record 38 of Set 6 | Vao.
# Processing Record 39 of Set 6 | Dikson.
# Processing Record 40 of Set 6 | Sao Francisco.
# Processing Record 41 of Set 6 | Salumbar.
# Processing Record 42 of Set 6 | Faanui.
# Processing Record 43 of Set 6 | Fukue.
# Processing Record 44 of Set 6 | Kabo.
# Processing Record 45 of Set 6 | Yanam.
# Processing Record 46 of Set 6 | Dali.
# Processing Record 47 of Set 6 | Manyoni.
# City not found. Skipping...
# City not found. Skipping...
# Processing Record 48 of Set 6 | Hudiksvall.
# Processing Record 49 of Set 6 | Puerto Colombia.
# Processing Record 50 of Set 6 | Ereymentau.
# Processing Record 1 of Set 7 | Norden.
# City not found. Skipping...
# Processing Record 2 of Set 7 | Rio Grande.
# Processing Record 3 of Set 7 | Ipameri.
# Processing Record 4 of Set 7 | Nemuro.
# Processing Record 5 of Set 7 | Rorvik.
# Processing Record 6 of Set 7 | Usinsk.
# Processing Record 7 of Set 7 | Pringsewu.
# Processing Record 8 of Set 7 | Tilichiki.
# Processing Record 9 of Set 7 | Norrtalje.
# Processing Record 10 of Set 7 | Petropavlovsk-Kamchatskiy.
# City not found. Skipping...
# Processing Record 11 of Set 7 | Iquitos.
# Processing Record 12 of Set 7 | Tabuk.
# Processing Record 13 of Set 7 | Port Augusta.
# Processing Record 14 of Set 7 | Aklavik.
# Processing Record 15 of Set 7 | Sioux Lookout.
# Processing Record 16 of Set 7 | Storforshei.
# Processing Record 17 of Set 7 | Ahipara.
# Processing Record 18 of Set 7 | Yagodnoye.
# Processing Record 19 of Set 7 | Viedma.
# Processing Record 20 of Set 7 | Sahuaripa.
# Processing Record 21 of Set 7 | Wamba.
# Processing Record 22 of Set 7 | Leh.
# Processing Record 23 of Set 7 | Sabzevar.
# Processing Record 24 of Set 7 | Luba.
# Processing Record 25 of Set 7 | Waingapu.
# Processing Record 26 of Set 7 | Mopipi.
# City not found. Skipping...
# Processing Record 27 of Set 7 | Mpika.
# Processing Record 28 of Set 7 | Promissao.
# City not found. Skipping...
# Processing Record 29 of Set 7 | Ankazobe.
# Processing Record 30 of Set 7 | Pochutla.
# Processing Record 31 of Set 7 | Lima.
# Processing Record 32 of Set 7 | Cayenne.
# Processing Record 33 of Set 7 | Los Andes.
# Processing Record 34 of Set 7 | Jardim.
# Processing Record 35 of Set 7 | Hillsboro.
# Processing Record 36 of Set 7 | Channel-Port aux Basques.
# Processing Record 37 of Set 7 | Lerwick.
# City not found. Skipping...
# Processing Record 38 of Set 7 | Russell.
# Processing Record 39 of Set 7 | Ostersund.
# Processing Record 40 of Set 7 | Antalaha.
# Processing Record 41 of Set 7 | Leningradskiy.
# Processing Record 42 of Set 7 | Thinadhoo.
# Processing Record 43 of Set 7 | Salair.
# Processing Record 44 of Set 7 | Pachino.
# Processing Record 45 of Set 7 | Ilulissat.
# Processing Record 46 of Set 7 | Puerto del Rosario.
# Processing Record 47 of Set 7 | Lavrentiya.
# Processing Record 48 of Set 7 | Corowa.
# Processing Record 49 of Set 7 | Santa Rosa.
# Processing Record 50 of Set 7 | Wageningen.
# Processing Record 1 of Set 8 | Ayan.
# Processing Record 2 of Set 8 | Muyuka.
# Processing Record 3 of Set 8 | Grand Gaube.
# City not found. Skipping...
# Processing Record 4 of Set 8 | Churuquita Chiquita.
# Processing Record 5 of Set 8 | Srednekolymsk.
# Processing Record 6 of Set 8 | Karema.
# Processing Record 7 of Set 8 | Noshiro.
# Processing Record 8 of Set 8 | Sao Joao da Barra.
# Processing Record 9 of Set 8 | Coihaique.
# Processing Record 10 of Set 8 | Sechura.
# Processing Record 11 of Set 8 | Guymon.
# Processing Record 12 of Set 8 | Inuvik.
# Processing Record 13 of Set 8 | Murdochville.
# Processing Record 14 of Set 8 | Port Hardy.
# Processing Record 15 of Set 8 | Vavuniya.
# Processing Record 16 of Set 8 | Tsumeb.
# Processing Record 17 of Set 8 | Altay.
# Processing Record 18 of Set 8 | Sao Filipe.
# Processing Record 19 of Set 8 | Bushehr.
# Processing Record 20 of Set 8 | Pacific Grove.
# Processing Record 21 of Set 8 | Lata.
# Processing Record 22 of Set 8 | Te Anau.
# Processing Record 23 of Set 8 | Mandurah.
# Processing Record 24 of Set 8 | Pauini.
# Processing Record 25 of Set 8 | Liaocheng.
# Processing Record 26 of Set 8 | Coromandel.
# City not found. Skipping...
# Processing Record 27 of Set 8 | Sao Jose da Coroa Grande.
# Processing Record 28 of Set 8 | Gat.
# Processing Record 29 of Set 8 | Guilin.
# Processing Record 30 of Set 8 | Dakar.
# Processing Record 31 of Set 8 | Sangrur.
# Processing Record 32 of Set 8 | Manaus.
# Processing Record 33 of Set 8 | Kaputa.
# Processing Record 34 of Set 8 | Kalmunai.
# Processing Record 35 of Set 8 | Haicheng.
# Processing Record 36 of Set 8 | Maturin.
# Processing Record 37 of Set 8 | Oranjemund.
# Processing Record 38 of Set 8 | Jimo.
# City not found. Skipping...
# Processing Record 39 of Set 8 | Yangambi.
# Processing Record 40 of Set 8 | Hofn.
# Processing Record 41 of Set 8 | Yerbogachen.
# Processing Record 42 of Set 8 | Menongue.
# Processing Record 43 of Set 8 | Isangel.
# Processing Record 44 of Set 8 | Luderitz.
# Processing Record 45 of Set 8 | Ternate.
# Processing Record 46 of Set 8 | Canandaigua.
# Processing Record 47 of Set 8 | Nuuk.
# Processing Record 48 of Set 8 | Bulgan.
# Processing Record 49 of Set 8 | Panzhihua.
# City not found. Skipping...
# Processing Record 50 of Set 8 | Bontang.
# Processing Record 1 of Set 9 | Lagoa.
# Processing Record 2 of Set 9 | Tazovskiy.
# Processing Record 3 of Set 9 | Kedrovyy.
# Processing Record 4 of Set 9 | Nizhniy Mamon.
# Processing Record 5 of Set 9 | Mae Sai.
# City not found. Skipping...
# Processing Record 6 of Set 9 | Beira.
# Processing Record 7 of Set 9 | Lorengau.
# Processing Record 8 of Set 9 | Bati.
# Processing Record 9 of Set 9 | Cururupu.
# Processing Record 10 of Set 9 | Cedar City.
# City not found. Skipping...
# Processing Record 11 of Set 9 | Sao Felix do Xingu.
# Processing Record 12 of Set 9 | Inndyr.
# Processing Record 13 of Set 9 | Zhangjiakou.
# Processing Record 14 of Set 9 | Broken Hill.
# Processing Record 15 of Set 9 | Maceio.
# Processing Record 16 of Set 9 | Henties Bay.
# Processing Record 17 of Set 9 | Adre.
# Processing Record 18 of Set 9 | Moron.
# Processing Record 19 of Set 9 | Galle.
# Processing Record 20 of Set 9 | Airai.
# Processing Record 21 of Set 9 | Beterou.
# Processing Record 22 of Set 9 | Nanyamba.
# Processing Record 23 of Set 9 | Makakilo City.
# Processing Record 24 of Set 9 | Xaltocan.
# Processing Record 25 of Set 9 | Sao Gabriel da Cachoeira.
# Processing Record 26 of Set 9 | Nhamunda.
# Processing Record 27 of Set 9 | Okha.
# Processing Record 28 of Set 9 | Mago.
# Processing Record 29 of Set 9 | Serenje.
# Processing Record 30 of Set 9 | Vanavara.
# Processing Record 31 of Set 9 | Rio Cuarto.
# Processing Record 32 of Set 9 | Abu Samrah.
# City not found. Skipping...
# Processing Record 33 of Set 9 | Karratha.
# Processing Record 34 of Set 9 | Rawson.
# Processing Record 35 of Set 9 | Humaita.
# Processing Record 36 of Set 9 | Matagami.
# City not found. Skipping...
# Processing Record 37 of Set 9 | Inta.
# Processing Record 38 of Set 9 | Clovis.
# Processing Record 39 of Set 9 | Port Macquarie.
# City not found. Skipping...
# Processing Record 40 of Set 9 | Mehamn.
# City not found. Skipping...
# Processing Record 41 of Set 9 | Port Lincoln.
# Processing Record 42 of Set 9 | Troitsko-Pechorsk.
# Processing Record 43 of Set 9 | Boa Vista.
# Processing Record 44 of Set 9 | Taltal.
# Processing Record 45 of Set 9 | Chippenham.
# Processing Record 46 of Set 9 | Hamilton.
# Processing Record 47 of Set 9 | Chunskiy.
# Processing Record 48 of Set 9 | Itaituba.
# Processing Record 49 of Set 9 | Samdrup Jongkhar.
# City not found. Skipping...
# Processing Record 50 of Set 9 | Stromness.
# Processing Record 1 of Set 10 | Shar.
# Processing Record 2 of Set 10 | Auki.
# Processing Record 3 of Set 10 | Lakatoro.
# Processing Record 4 of Set 10 | Hirara.
# Processing Record 5 of Set 10 | Oktyabrskiy.
# Processing Record 6 of Set 10 | Isilkul.
# Processing Record 7 of Set 10 | Hauterive.
# Processing Record 8 of Set 10 | Tieling.
# Processing Record 9 of Set 10 | Buenos Aires.
# Processing Record 10 of Set 10 | Caravelas.
# Processing Record 11 of Set 10 | Ghatanji.
# Processing Record 12 of Set 10 | Le Port.
# Processing Record 13 of Set 10 | Maningrida.
# Processing Record 14 of Set 10 | Uglezavodsk.
# City not found. Skipping...
# Processing Record 15 of Set 10 | Hovd.
# Processing Record 16 of Set 10 | Sa Kaeo.
# Processing Record 17 of Set 10 | Yar.
# City not found. Skipping...
# Processing Record 18 of Set 10 | Rio Gallegos.
# Processing Record 19 of Set 10 | Kayiry.
# Processing Record 20 of Set 10 | Svetlogorsk.
# Processing Record 21 of Set 10 | Chikhli.
# Processing Record 22 of Set 10 | Kyshtovka.
# City not found. Skipping...
# Processing Record 23 of Set 10 | Malartic.
# Processing Record 24 of Set 10 | Rafai.
# City not found. Skipping...
# Processing Record 25 of Set 10 | Matara.
# Processing Record 26 of Set 10 | Belmonte.
# City not found. Skipping...
# Processing Record 27 of Set 10 | Verkhnyaya Toyma.
# Processing Record 28 of Set 10 | Cabedelo.
# Processing Record 29 of Set 10 | Bam.
# Processing Record 30 of Set 10 | Agirish.
# Processing Record 31 of Set 10 | San Antonio.
# Processing Record 32 of Set 10 | Itaberai.
# Processing Record 33 of Set 10 | Sivaki.
# Processing Record 34 of Set 10 | Paamiut.
# Processing Record 35 of Set 10 | Bela.
# Processing Record 36 of Set 10 | Kilindoni.
# Processing Record 37 of Set 10 | Lagunas.
# Processing Record 38 of Set 10 | Tomakomai.
# Processing Record 39 of Set 10 | Fort Nelson.
# Processing Record 40 of Set 10 | Wagrowiec.
# Processing Record 41 of Set 10 | Sola.
# Processing Record 42 of Set 10 | Ceuta.
# Processing Record 43 of Set 10 | Manali.
# Processing Record 44 of Set 10 | Mantenopolis.
# Processing Record 45 of Set 10 | Stykkisholmur.
# Processing Record 46 of Set 10 | Poya.
# Processing Record 47 of Set 10 | Olinda.
# Processing Record 48 of Set 10 | Chumikan.
# Processing Record 49 of Set 10 | Ongandjera.
# Processing Record 50 of Set 10 | Halmasd.
# Processing Record 1 of Set 11 | Tupik.
# Processing Record 2 of Set 11 | Umea.
# Processing Record 3 of Set 11 | Orocue.
# Processing Record 4 of Set 11 | Mandalgovi.
# Processing Record 5 of Set 11 | San Pedro.
# City not found. Skipping...
# Processing Record 6 of Set 11 | Bandarbeyla.
# Processing Record 7 of Set 11 | Port-Gentil.
# Processing Record 8 of Set 11 | College.
# Processing Record 9 of Set 11 | Laguna.
# Processing Record 10 of Set 11 | Maragogi.
# Processing Record 11 of Set 11 | Xichang.
# Processing Record 12 of Set 11 | Poum.
# Processing Record 13 of Set 11 | Ferrol.
# City not found. Skipping...
# Processing Record 14 of Set 11 | Saquena.
# Processing Record 15 of Set 11 | Xining.
# Processing Record 16 of Set 11 | Kieta.
# Processing Record 17 of Set 11 | Abu Dhabi.
# Processing Record 18 of Set 11 | Strezhevoy.
# Processing Record 19 of Set 11 | Paita.
# Processing Record 20 of Set 11 | Tagusao.
# Processing Record 21 of Set 11 | San Lorenzo.
# Processing Record 22 of Set 11 | Waipawa.
# Processing Record 23 of Set 11 | Qaqortoq.
# Processing Record 24 of Set 11 | Dunedin.
# Processing Record 25 of Set 11 | Balikpapan.
# Processing Record 26 of Set 11 | Chernogorsk.
# Processing Record 27 of Set 11 | Teya.
# Processing Record 28 of Set 11 | Meulaboh.
# Processing Record 29 of Set 11 | Alta Gracia.
# Processing Record 30 of Set 11 | Cockburn Town.
# Processing Record 31 of Set 11 | Caluquembe.
# Processing Record 32 of Set 11 | Ambilobe.
# Processing Record 33 of Set 11 | Fare.
# Processing Record 34 of Set 11 | Morehead.
# Processing Record 35 of Set 11 | Orbetello.
# Processing Record 36 of Set 11 | Anloga.
# Processing Record 37 of Set 11 | Urgut.
# Processing Record 38 of Set 11 | Luwingu.
# Processing Record 39 of Set 11 | Allonnes.
# Processing Record 40 of Set 11 | Granja.

# %% [markdown]
# ### Convert Raw Data to DataFrame
# * Export the city data into a .csv.
# * Display the DataFrame

# %%
# Converting Raw Data to DataFrame
weather_data = pd.DataFrame(all_in_one,
                            columns=['City', 'Cloudiness', 'Country','Date',
                                     'Humidity','Lat','lng','Max Temp','Wind Speed'])

# Writing data to csv file
weather_data.to_csv(output_data_file, header=True, index=True, index_label= 'Index')

# %%
weather_data.count()

# %%
weather_data.head(5)

# %% [markdown]
# ### Plotting the Data
# * Use proper labeling of the plots using plot titles (including date of analysis) and axes labels.
# * Save the plotted figures as .pngs.

# %% [markdown]
# #### Latitude vs. Temperature Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Max Temp', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Max Temperature (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Max Temperature (F)')
plt.savefig('output_data/Lat_vs_Temp.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Humidity Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Humidity', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Humidity (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Humidity (%)')
plt.savefig('output_data/Lat_vs_Humidity.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Cloudiness Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Cloudiness', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Cloudiness (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Cloudiness (%)')
plt.savefig('output_data/Lat_vs_Cloudiness.png', bbox_inches="tight")

# %% [markdown]
# #### Latitude vs. Wind Speed Plot

# %%
ax1 = weather_data.plot.scatter(x='Lat', y='Wind Speed', c='DarkBlue')

# Adding grid, title, and labels
plt.grid(True)
plt.title('City Latitude vs. Wind Speed (' + time.strftime("%m/%d/%y") + ')')
plt.xlabel('Latitude')
plt.ylabel('Wind Speed (mph)')
plt.savefig('output_data/Lat_vs_WindSpeed.png', bbox_inches="tight")

# %% [markdown]
# ### Observable trends
# * 1. The temperature is highest 20 to 40 degrees north of the equator, which is consistent with the seasonal expectation.
# * 2. Cloud coverage is consistent world-wide and across the range of latitude.
# * 3. Wind speeds show a slight peak around the equator.
